# %%
class Point:
    def __init__(self,x,y):
        self.x_cod = x
        self.y_cod = y
        
    def __str__(self):
        #return f"{self.x_cod,self.y_cod}"
        return '<{},{}>'.format(self.x_cod,self.y_cod)
    
    def euclidean_distance(self,other):
        return ((self.x_cod - other.x_cod)**2 + (self.x_cod - other.x_cod)**2)**0.5
    
    def distance_from_origin(self):
        return self.euclidean_distance(Point(0,0))
    
    
class Line:
    def __init__(self,A,B,C):
        self.A = A
        self.B = B
        self.C = C
        
    def __str__(self):
        return '{}x + {}y + {} = 0'.format(self.A,self.B,self.C)
    
    def point_on_line(line,point):
        if line.A*point.x_cod + line.B*point.y_cod + line.C == 0:
            return "Point lies on line"
        else:
            return "Point doesnot lie on line"
    
    def shortest_distance(line,point):
        return abs(line.A*point.x_cod + line.B*point.y_cod + line.C)/(line.A**2 + line.B**2)**0.5

# %%
l1 = Line(1,1,-2)
p = Point(1,1)
print(l1)
print(p)
l1.point_on_line(p)
l1.shortest_distance(p)
# Out:
# 1x + 1y + -2 = 0
# <1,1>
# 0.0

# %%
p1 = Point(0,0)
p2 = Point(10,10)
p1.euclidean_distance(p2)
p2.distance_from_origin()
# Out:
# 14.142135623730951

# %%
print(p1)
print(p2)
# Out:
# <0,0>
# <10,10>

# %%
#how object access attributes

# %%
class Person:
    
    def __init__(self,name_input,country_input):
        self.name_input = name_input
        self.country_input = country_input
        
    def greet(self):
        if self.country_input == 'Nepal':
            print(f'Namaste {self.name_input}')
        else:
            print(f'Hello {self.name_input}')

# %%
#how to access attributes
d1 = Person('Rikesh','Nepal')

# %%
d1.greet()
# Out:
# Namaste Rikesh

# %% [markdown]
# # Attribute creation from outside of class

# %%
d1.gender = 'Male'

# %%
d1.gender
# Out:
# 'Male'

# %% [markdown]
# # Reference Variable
# * reference variable holds the objects
# * we can create objects without reference variable as well
# * An object can have multiple reference variable
# * Assigning a new reference variable to an existing object doesnot create a new object

# %%
class Person:
    
    def __init__(self):
        self.name = 'Rikesh'
        self.gender = 'Male'

        
Person()

# %%
# p is not the object of the person but it stores the reference to the memory location where the object of the Person class is created 
p= Person()
q = p

# %%
print(id(p))
print(id(q))
# Out:
# 140005469499216
# 140005469499216

# %%
print(p.name)
print(q.name)
q.name = 'Shah'
print(q.name)
print(p.name)
# Out:
# Rikesh
# Rikesh
# Shah
# Shah

# %% [markdown]
# # Pass by Reference

# %%
class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
    
def greet(person):
    print(f'Hi my name is {person.name} and i am {person.gender}')
    p1 = Person('Shah','Female')
    return p1
    
p = Person('Rikesh','Male')
x = greet(p)
print(x.name)
print(x.gender)
# Out:
# Hi my name is Rikesh and i am Male
# Shah
# Female

# %%
class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
    
def greet(person):
    print(id(person))
    person.name = 'Shah'
    print(person.name)
    
p = Person('Rikesh','Male')
print(id(p))
greet(p)
print(p.name)
# Out:
# 140005469493600
# 140005469493600
# Shah
# Shah

# %% [markdown]
# # Object's Mutability

# %%
class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
    
def greet(person):
    person.name = 'Shah'
    return person
    
p = Person('Rikesh','Male')
print(id(p))
p1 = greet(p)
print(id(p1))
# Out:
# 140005469501328
# 140005469501328

# %% [markdown]
# #  Encapsulation

# %%
class Person:
    def __init__(self, name_input, country_input):
        self.name = name_input
        self.country = country_input
    

P1 = Person('Rikesh','Nepal')
P2 = Person('Shah','USA')

# %%
P2.name
P1.name
# Out:
# 'Rikesh'

# %%
class Atm:
    def __init__(self):
        #print(id(self))  #prints the memory address of self
        self.pin = ''
        self.__balance = 0
        self.menu()
    
    def get_balance(self):
        return self.__balance
    
    def set_balance(self,new_value):
        if type(new_value) == int:
            self.__balance = new_value
        else:
            print('Goli kha k manega k')
    
    def menu(self):
        user_input = input("""
        Hi how can I help you?
        1. Press 1 to create pin
        2. Press 2 to chnage pin
        3. Press 3 to check balance
        4. Press 4 to withdraw
        5. Anything else to exit
        """)
        
        if user_input == '1':
            #create pin
            self.create_pin()
        elif user_input == '2':
            #Change pin
            self.change_pin()
        elif user_input == '3':
            #check balance
            self.check_balance()
        elif user_input == '4':
            #withdraw
            self.withdraw()
        else:
            exit()
        
    
    def create_pin(self):
        user_pin = input("Enter your Pin")
        self.pin = user_pin
        user_balance = int(input("Enter your Balance"))
        self.__balance = user_balance
        print('Pin created successfully')
        self.menu()
        
    def change_pin(self):
        old_pin = input("Enter your old pin")
        if old_pin == self.pin:
            #let the user change the pin
            new_pin = input("Enter your new Pin")
            self.pin = new_pin
            print('Pin changed successfully')
            #self.menu()
        else:
            print("Pehli Fursat mein nikal chutiye.")
            #self.menu()
        self.menu()
            
    def check_balance(self):
        user_pin = input("Enter your pin")
        if user_pin == self.pin:
            print(f"Your balance is {self.__balance}")
        else:
            print("Bhaak bhosdike")
            
    def withdraw(self):
        user_pin = input("Enter your pin")
        if user_pin == self.pin:
            #allow to withdraw
            amount = int(input("Enter the amount"))
            if amount <= self.__balance:
                self.balance = self.__balance - amount
                print(f"Withdrawl successful\n your current balance is {self.__balance}")
            else:
                print("Bhikhari")
        else:
            print('Muh na kan tipuwa naam')
        self.menu()

# %%
obj = Atm()
# Out:
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to chnage pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#          1
# Enter your Pin 1234
# Enter your Balance 10000
# Pin created successfully
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. Press 2 to chnage pin
#         3. Press 3 to check balance
#         4. Press 4 to withdraw
#         5. Anything else to exit
#          7

# %%
obj.check_balance()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 obj.check_balance()
#
# NameError: name 'obj' is not defined

# %%
obj.set_balance(1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 obj.set_balance(1000)
#
# NameError: name 'obj' is not defined

# %%
class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
        
p1 = Person('rikesh','male')
p2 = Person('kumar','male')
p3 = Person('shah','male')

L =[p1,p2,p3]

print(L)

for i in L:
    print(i.name,i.gender)
# Out:
# [<__main__.Person object at 0x7b8c79a2d990>, <__main__.Person object at 0x7b8c79a2e560>, <__main__.Person object at 0x7b8c79a2dcc0>]
# rikesh male
# kumar male
# shah male

# %% [markdown]
# # Collection of Objects

# %%
class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
        
p1 = Person('rikesh','male')
p2 = Person('kumar','male')
p3 = Person('shah','male')

L ={'p1':p1,'p2':p2,'p3':p3}

print(L)

for i in L:
    print(i)
    
for i in L:
    print(L[i])
    
for i in L:
    print(L[i].name,L[i].gender)
# Out:
# {'p1': <__main__.Person object at 0x7b8c79a2f910>, 'p2': <__main__.Person object at 0x7b8c79a2e800>, 'p3': <__main__.Person object at 0x7b8c79a2e890>}
# p1
# p2
# p3
# ...
# rikesh male
# kumar male
# shah male

# %% [markdown]
# # Static Variables (vs Instance Variables)

# %%
 class Atm:
    __counter =1
    def __init__(self):
        #print(id(self))  #prints the memory address of self
        self.pin = ''
        self.__balance = 0
        self.cid = Atm.__counter
        Atm.__counter += 1
        #self.menu()
    
    #utility methods
    @staticmethod   
    def get_counter():
        return Atm.__counter
    
    def get_balance(self):
        return self.__balance
    
    def set_balance(self,new_value):
        if type(new_value) == int:
            self.__balance = new_value
        else:
            print('Goli kha k manega k')
    
    def menu(self):
        user_input = input("""
        Hi how can I help you?
        1. Press 1 to create pin
        2. Press 2 to chnage pin
        3. Press 3 to check balance
        4. Press 4 to withdraw
        5. Anything else to exit
        """)
        
        if user_input == '1':
            #create pin
            self.create_pin()
        elif user_input == '2':
            #Change pin
            self.change_pin()
        elif user_input == '3':
            #check balance
            self.check_balance()
        elif user_input == '4':
            #withdraw
            self.withdraw()
        else:
            exit()
        
    
    def create_pin(self):
        user_pin = input("Enter your Pin")
        self.pin = user_pin
        user_balance = int(input("Enter your Balance"))
        self.__balance = user_balance
        print('Pin created successfully')
        self.menu()
        
    def change_pin(self):
        old_pin = input("Enter your old pin")
        if old_pin == self.pin:
            #let the user change the pin
            new_pin = input("Enter your new Pin")
            self.pin = new_pin
            print('Pin changed successfully')
            #self.menu()
        else:
            print("Pehli Fursat mein nikal chutiye.")
            #self.menu()
        self.menu()
            
    def check_balance(self):
        user_pin = input("Enter your pin")
        if user_pin == self.pin:
            print(f"Your balance is {self.__balance}")
        else:
            print("Bhaak bhosdike")
            
    def withdraw(self):
        user_pin = input("Enter your pin")
        if user_pin == self.pin:
            #allow to withdraw
            amount = int(input("Enter the amount"))
            if amount <= self.__balance:
                self.balance = self.__balance - amount
                print(f"Withdrawl successful\n your current balance is {self.__balance}")
            else:
                print("Bhikhari")
        else:
            print('Muh na kan tipuwa naam')
        self.menu()

# %%
c1 = Atm()

# %%
c2 = Atm()

# %%
c3 = Atm()

# %%
c3 .cid
# Out:
# 3

# %%
c = Atm()

# %%
Atm.get_counter()
# Out:
# 5
